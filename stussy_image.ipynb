# %%
from selenium import webdriver
from selenium.webdriver import ActionChains
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
from PIL import Image
import time
import os
import urllib.request

# #옵션 headless
# options = webdriver.ChromeOptions()
# options.headless = True

List_1 = [6412108502]

count = 1
for i in List_1:
    URL = 'https://smartstore.naver.com/europeinroom/products/' + str(i)
    driver = webdriver.Chrome(ChromeDriverManager().install(), options=options) 
    driver.get(URL)

    s = driver.find_elements_by_css_selector('._2Yq5J2HeBn > li')
    z = driver.find_element_by_css_selector('._23RpOU6xpc')

    for m in range(len(s)):
        webdriver.ActionChains(driver).move_to_element(s[m]).perform()
        time.sleep(0.05) 
        webdriver.ActionChains(driver).move_to_element(z).perform()
     
    q = driver.find_elements_by_css_selector('._37ptkngDmo > img')

    count1 = 1
    for xx in q: 
        print(xx.get_attribute('src'))
        urllib.request.urlretrieve(xx.get_attribute('src'),'{}_{}.png'.format(str(i),count1))
        count1 +=1

# %%
from selenium import webdriver
from selenium.webdriver import ActionChains
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
from PIL import Image
import time
import os
import urllib.request
from bs4 import BeautifulSoup
import re

urls ='https://www.stussy.com/collections/overdyed/products/stock-logo-ss-pocket-crew?variant=39435570839648'+'_?glCountry=US&glCurrency=USD'

driver = webdriver.Chrome(ChromeDriverManager().install())
driver.get(urls)
    # driver.set_window_size(1920,1080)

    #scroll bottom
footer_ = driver.find_element_by_css_selector('.site-footer__copyright')
webdriver.ActionChains(driver).move_to_element(footer_).perform()
    #find element
pro_name = driver.find_element_by_css_selector('.product__title')
pro_color = driver.find_element_by_css_selector('.product__title')
    #make directory
os.makedirs(pro_name.text/pro_color.text, exist_ok=True)
    # zoom_1 = driver.find_element_by_css_selector('#slick-slide40 > a > div > img')
time.sleep(1)
    # driver.get(urls+'#product-image-zoom')
    # time.sleep(1)
pro_image = driver.find_element_by_css_selector('.product__images')
tt_ = pro_image.get_attribute('innerHTML')
soup = BeautifulSoup(tt_, 'html.parser')

res_ = soup.find_all("img", class_="lazyautosizes lazyloaded")
count = 1
for i in res_:
    xx = str(i).split(",")[5].split('.jpg')
    yy = xx[0] + ".jpg"
    zz ="https:"+yy[1:]
    urllib.request.urlretrieve(zz,"{}.jpg".format(count))
    print(count)
    count+=1

# print(res_)
print(soup.find_all("meta", {"property":"og:image"}))
# webdriver.ActionChains(driver).move_to_element(zoom_1)

# %%
from selenium import webdriver
from selenium.webdriver import ActionChains
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
from PIL import Image
import time
import os
import urllib.request
from bs4 import BeautifulSoup
import re
from rembg.bg import remove

urls =[
"https://www.stussy.com/products/big-logo-twill-bucket-hat-1?pr_prod_strat=description&pr_rec_id=6b3ecc4c3&pr_rec_pid=4790954819680&pr_ref_pid=4682396074080&pr_seq=uniform?variant=32919810965600"
]

options = webdriver.ChromeOptions()
options.headless = True
count_ = 1
for url in urls:
    driver = webdriver.Chrome(ChromeDriverManager().install(), options=options)
    driver.get(url)
    #요소 찾기 +'_?glCountry=US&glCurrency=USD'
    pro_name = driver.find_element_by_css_selector('.product__title')
    
    footer_ = driver.find_element_by_css_selector('.site-footer__copyright')
    print(pro_name.text)
    #하단 스크롤
#     webdriver.ActionChains(driver).move_to_element(footer_).perform()
#     time.sleep(0.5)
    S = lambda X: driver.execute_script('return document.body.parentNode.scroll'+X)
    time.sleep(3)
    driver.set_window_size(S("Width"),S('Height')) # May need manual adjustment
    #display none 이라 ? 
    pro_color = driver.find_element_by_css_selector('.product__images')
    qq = pro_color.get_attribute('innerHTML')
    soup = BeautifulSoup(qq, 'html.parser')
    dir_color = soup.find("img","lazyautosizes lazyloaded").attrs['alt']
    q_ = soup.find_all("img","lazyautosizes lazyloaded")
    new_color = re.sub(r"[^a-zA-Z0-9 ]","",pro_name.text)
    new_color_ = re.sub(r"[^a-zA-Z0-9 ]","",pro_color.text)
    print(pro_color.text)
    #makedirs > fileExistError
    os.makedirs('./{}'.format(new_color), exist_ok=True)
    

        

    
#     isExist = os.path.exists(path)

#     if not isExist:
  
#     # Create a new directory because it does not exist 
#     os.makedirs(path)
    
    count__ = 1
    for xx in q_:
        link_ = 'https:'+ xx.attrs['data-srcset'].split(',')[5][1:].split('.jpg')[0] + '.jpg'
        print(link_)
        urllib.request.urlretrieve(link_,"{}/{}_{}.jpg".format(new_color,new_color_,count__))
        count__ += 1
    driver.quit()
    print("{} / {}".format(count_,len(urls)))
    count_ += 1
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 99.0.4844
# Get LATEST chromedriver version for 99.0.4844 google-chrome
# Driver [C:\Users\Wook\.wdm\drivers\chromedriver\win32\99.0.4844.51\chromedriver.exe] found in cache
# C:\Users\Wook\AppData\Local\Temp/ipykernel_34032/2008226089.py:21: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install(), options=options)
# C:\Users\Wook\AppData\Local\Temp/ipykernel_34032/2008226089.py:24: DeprecationWarning: find_element_by_css_selector is deprecated. Please use find_element(by=By.CSS_SELECTOR, value=css_selector) instead
#   pro_name = driver.find_element_by_css_selector('.product__title')
# C:\Users\Wook\AppData\Local\Temp/ipykernel_34032/2008226089.py:26: DeprecationWarning: find_element_by_css_selector is deprecated. Please use find_element(by=By.CSS_SELECTOR, value=css_selector) instead
# ...

# %%
import pathlib 
pathlib.Path('/my/directory').mkdir(parents=True, exist_ok=True)
